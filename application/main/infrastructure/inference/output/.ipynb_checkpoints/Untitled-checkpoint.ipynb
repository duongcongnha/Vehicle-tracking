# %%
import pandas as pd
import numpy as np
from datetime import timedelta, datetime
from sqlalchemy import create_engine
import time

# %%
str(timedelta(seconds= time.time()))
# Out:
# '18999 days, 2:16:19.486269'

# %%
datetime.utcfromtimestamp(time.time())
# Out:
# datetime.datetime(2022, 1, 7, 2, 17, 49, 914327)

# %%
list_duration = {1: {'in': 2, 'exit': 187, 'duration attention': 19}, 2: {'in': 191, 'exit': -1, 'duration attention': 9}}

# %%
fps = 25

# %%
df_dur = pd.DataFrame(list_duration).T.reset_index()
df_dur.columns = ['ID', 'in', 'exit', 'duration attention']

# %%
df_dur
# Out:
#    ID   in  exit  duration attention
# 0   1    2   187                  19
# 1   2  191    -1                   9

# %%
frame_idx = 322
end_time =  str(timedelta(seconds=frame_idx/fps))
for col in df_dur.columns[1:]:
    df_dur[col] = (df_dur[col]/fps).apply(lambda x: str(timedelta(seconds=x)) if x>0 else end_time)

# %%
df_dur
# Out:
#    ID              in            exit duration attention
# 0   1  0:00:00.080000  0:00:07.480000     0:00:00.760000
# 1   2  0:00:07.640000  0:00:12.880000     0:00:00.360000

# %%
person = df_dur

# %%
person.iloc[0, :].exit
# Out:
# '0:00:07.480000'

# %%
engine = create_engine('postgresql+pg8000://postgres:root2351@localhost:5432/face_store')

df_dur.to_sql("front_store_IDs_notebook", engine, if_exists='replace')

# %%
datetime.datetime(19, 36, 46, 633199)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16380/2357969004.py in <module>
# ----> 1 datetime.datetime(19, 36, 46, 633199)
#
# ValueError: month must be in 1..12

# %%
timedelta(seconds=120.5)
# Out:
# datetime.timedelta(seconds=120, microseconds=500000)

# %%
datetime.datetime.now() + timedelta(seconds=120)
# Out:
# datetime.datetime(2022, 1, 5, 19, 36, 46, 633199)

# %%
from datetime import datetime
s1 = '10:33:26:500000'
s2 = '11:15:49:200000' # for example
FMT = '%H:%M:%S:%f'
datetime.strptime(s2, FMT) - datetime.strptime(s1, FMT)


t = datetime.strptime("05:20:25","%H:%M:%S")
# ...and use datetime's hour, min and sec properties to build a timedelta
delta = timedelta(hours=t.hour, minutes=t.minute, seconds=t.second)
# Out:
# datetime.timedelta(seconds=2542, microseconds=700000)

# %%
datetime.now().timestamp()
# Out:
# 1641462994.04805

# %%
cc = [123, -1]

# %%
cc[1] = 234

# %%
engine = create_engine('postgresql+pg8000://postgres:root2351@localhost:5432/face_store')

df_dur.to_sql("front_store_IDs", engine, if_exists='replace')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:717: UserWarning: the 'timedelta' type is not supported, and will be written as integer values (ns frequency) to the database.
#   pandas_sql.to_sql(

# %%
import psycopg2


connection = psycopg2.connect(user="postgres",
                              password="root2351",
                              host="localhost",
                              port="5432",
                              database="face_store")
cursor = connection.cursor()
postgreSQL_select_Query = 'SELECT * FROM public."front_store_IDs"'

cursor.execute(postgreSQL_select_Query)

df_dur = cursor.fetchall()

# %%
engine = create_engine('postgresql+pg8000://postgres:root2351@localhost:5432/face_store');

df_dur = pd.read_sql('SELECT * FROM public."person"', engine.connect())

# %%
person = [None] * len(df_dur)
for i in range(len(person)):
    person[i] = df_dur.iloc[i, :]

# %%
import os
import sys
from sqlalchemy import Column, ForeignKey, Integer, String, DateTime, Interval
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker
from sqlalchemy import create_engine


Base = declarative_base()

class Person(Base):
    __tablename__ = 'person2'
    # Here we define columns for the table person
    # Notice that each column is also a normal Python instance attribute.
    ID = Column(String, primary_key=True)
    in_time = Column(DateTime)
    exit_time = Column(DateTime)
    duration_attention = Column(Interval)
    
    def __init__(self, ID, in_time, exit_time, duration_attention):
        self.ID = ID
        self.in_time = in_time
        self.exit_time = exit_time
        self.duration_attention = duration_attention

engine = create_engine('postgresql+psycopg2://postgres:root2351@localhost:5432/face_store')

# Create all tables in the engine. This is equivalent to "Create Table" statements in raw SQL.
Base.metadata.create_all(engine)

# %%
engine = create_engine('postgresql+psycopg2://postgres:root2351@localhost:5432/face_store')
# use session_factory() to get a new Session
_SessionFactory = sessionmaker(bind=engine)

Base = declarative_base()
def session_factory():
    Base.metadata.create_all(engine)
    return _SessionFactory()

# %%
def add_person_to_db(person):
    session = session_factory()
    session.add(person)
    session.commit()
    session.close() 

def get_all_persons():
    session = session_factory()
    people_query = session.query(Person)
    session.close()
    return people_query.all()

# %%
person1 = Person(5, datetime.now(), datetime.now() + timedelta(seconds=120), timedelta(seconds=60))

# %%
0.5*(datetime.now() + timedelta(seconds=120) - datetime.now())
# Out:
# datetime.timedelta(seconds=60)

# %%
add_person_to_db(person1)

# %%
engine = create_engine('postgresql+psycopg2://postgres:root2351@localhost:5432/face_store')
Base.metadata.bind = engine

DBSession = sessionmaker()
DBSession.bind = engine
session = DBSession()
#Make a query to find all Persons in the database
session.query(Person).all()

# %%
# Return the first Person from all Persons in the database
person1 = session.query(Person).first()
person1.in_time
# Out:
# '0:00:00.480000'

# %%
# Find all Address whose person field is pointing to the person object
person5 = session.query(Person).filter(Person.ID == 5).all()

# %%
# Retrieve one Address whose person field is point to the person object
session.query(Address).filter(Address.person == person).one()
<sqlalchemy_declarative.Address object at 0x2ee3cd0>

# %%
address = session.query(Address).filter(Address.person == person).one()
address.post_code

# %%
df_dur[[x for x in df_dur.columns]]
# Out:
#      ID    in  exit  duration attention
# 0  0.04  0.08  7.48                0.76
# 1  0.08  7.64 -0.04                0.36

# %%
isinstance(df_dur, pd.core.frame.DataFrame)
# Out:
# True

# %%
str(timedelta(seconds=1000))
# Out:
# '0:16:40'

# %%
str(3)+"-"+str(time.time()).replace(".", "")
# Out:
# '3-16415310110532403'

# %%
import copy

# %%
isinstance(2, np.int32)
# Out:
# False

# %%
df_dur.dtypes
# Out:
# ID                     int64
# in                    object
# exit                  object
# duration attention    object
# dtype: object

# %%
df_tl = pd.read_csv("timeline.csv").iloc[:, 1:]

# %%
df_tl
# Out:
#                time  frame  n_pp_at_time  n_attentive_pp_at_time IDs_people  \
# 0    0:00:00.400000     10             0                     NaN        NaN
# 1    0:00:00.440000     11             0                     NaN        NaN
# 2    0:00:00.480000     12             1                     0.0        [1]
# 3    0:00:00.520000     13             1                     0.0        [1]
# 4    0:00:00.560000     14             1                     0.0        [1]
# ..              ...    ...           ...                     ...        ...
# 431  0:00:21.120000    528             1                     0.0        [6]
# 432  0:00:21.160000    529             1                     0.0        [6]
# 433  0:00:21.200000    530             1                     0.0        [6]
# 434  0:00:21.240000    531             1                     0.0        [6]
# 435  0:00:21.280000    532             1                     0.0        [6]
#
# ...

# %%
df_tl.T
# Out:
#                                                0               1    \
# time                                0:00:00.400000  0:00:00.440000
# frame                                           10              11
# n_pp_at_time                                     0               0
# n_attentive_pp_at_time                         NaN             NaN
# IDs_people                                     NaN             NaN
# IDs_attention                                  NaN             NaN
# bb_people                                      NaN             NaN
# bb_attention                                   NaN             NaN
# total_pp_appear_uptotime                         0               0
# total_attentive_pp_appear_uptotime               0               0
#
#                                                               2    \
# time                                               0:00:00.480000
# frame                                                          12
# ...

# %%
df_tl.T.to_dict()
# Out:
# {0: {'time': '0:00:00.400000',
#   'frame': 10,
#   'n_pp_at_time': 0,
#   'n_attentive_pp_at_time': nan,
#   'IDs_people': nan,
#   'IDs_attention': nan,
#   'bb_people': nan,
#   'bb_attention': nan,
#   'total_pp_appear_uptotime': 0,
#   'total_attentive_pp_appear_uptotime': 0},
#  1: {'time': '0:00:00.440000',
#   'frame': 11,
#   'n_pp_at_time': 0,
#   'n_attentive_pp_at_time': nan,
#   'IDs_people': nan,
#   'IDs_attention': nan,
#   'bb_people': nan,
#   'bb_attention': nan,
#   'total_pp_appear_uptotime': 0,
#   'total_attentive_pp_appear_uptotime': 0},
#  2: {'time': '0:00:00.480000',
#   'frame': 12,
#   'n_pp_at_time': 1,
#   'n_attentive_pp_at_time': 0.0,
#   'IDs_people': '[1]',
#   'IDs_attention': nan,
#   'bb_people': '[array([  0, 148,  55, 472])]',
#   'bb_attention': nan,
#   'total_pp_appear_uptotime': 1,
#   'total_attentive_pp_appear_uptotime': 0},
#  3: {'time': '0:00:00.520000',
#   'frame': 13,
#   'n_pp_at_time': 1,
#   'n_attentive_pp_at_time': 0.0,
# ...

# %%
list_2_frames = [{'time': '0:00:01.280000',
  'frame': 32,
  'n_pp_at_time': 2,
  'n_attentive_pp_at_time': 0.0,
  'IDs_people': '[1, 2]',
  'IDs_attention': np.nan,
  'bb_people': '[array([  4,  54, 122, 421]), array([  2, 208, 170, 473])]',
  'bb_attention': np.nan,
  'total_pp_appear_uptotime': 2,
  'total_attentive_pp_appear_uptotime': 1},

{'time': '0:00:01.320000',
  'frame': 33,
  'n_pp_at_time': 2,
  'n_attentive_pp_at_time': 1.0,
  'IDs_people': '[1, 2]',
  'IDs_attention': '[1]',
  'bb_people': '[array([  1,  52, 127, 440]), array([  3, 210, 170, 473])]',
  'bb_attention': '[array([32, 84, 62, 62])]',
  'total_pp_appear_uptotime': 2,
  'total_attentive_pp_appear_uptotime': 1}]

# %%
list_2_frames[0]
# Out:
# {'time': '0:00:01.280000',
#  'frame': 32,
#  'n_pp_at_time': 2,
#  'n_attentive_pp_at_time': 0.0,
#  'IDs_people': '[1, 2]',
#  'IDs_attention': nan,
#  'bb_people': '[array([  4,  54, 122, 421]), array([  2, 208, 170, 473])]',
#  'bb_attention': nan,
#  'total_pp_appear_uptotime': 2,
#  'total_attentive_pp_appear_uptotime': 1}

# %%
current_frame['n_attentive_pp_at_time'] = 0.0,
current_frame['IDs_people'] = '[1, 2]',
current_frame['IDs_attention'] = nan,
current_frame['bb_people'] = '[array([  4,  54, 122, 421]), array([  2, 208, 170, 473])]',
current_frame['bb_attention'] = nan,
current_frame['total_pp_appear_uptotime'] = 2,
current_frame['total_attentive_pp_appear_uptotime'] = 1

# %%
cc={2:'ccc'}

# %%
for id in []:
    print(cc[id])

# %%
list_duration = {1: {'in_time': datetime(2022, 1, 6, 19, 0, 12, 899550), 'exit_time': datetime(2022, 1, 6, 19, 0, 41, 293587), 'start_attend': datetime(2022, 1, 6, 19, 0, 14, 8632), 'end_attend': datetime(2022, 1, 6, 19, 0, 34, 258307)}, 2: {'in_time': datetime(2022, 1, 6, 19, 0, 14, 102361), 'exit_time': datetime(2022, 1, 6, 19, 0, 33, 787490), 'start_attend': datetime(2022, 1, 6, 19, 0, 17, 429740), 'end_attend': datetime(2022, 1, 6, 19, 0, 31, 31471)}, 5: {'in_time': datetime(2022, 1, 6, 19, 0, 46, 566810), 'exit_time': datetime(2022, 1, 6, 19, 1, 13, 831532), 'start_attend': datetime(2022, 1, 6, 19, 1, 0, 662329), 'end_attend': datetime(2022, 1, 6, 19, 1, 9, 222789)}, 6: {'in_time': datetime(2022, 1, 6, 19, 0, 51, 758167), 'exit_time': -1, 'start_attend': datetime(2022, 1, 6, 19, 0, 56, 975664), 'end_attend': datetime(2022, 1, 6, 19, 1, 16, 440286)}}

# %%
df_dur = pd.DataFrame(list_duration).T.reset_index()

# %%
df_dur.loc[3, 'exit_time'] = datetime(2022, 1, 6, 19, 1, 13, 831532)

# %%
df_dur['exit_time'] = pd.to_datetime(df_dur['exit_time'])

# %%
df_dur['duration'] = df_dur['exit_time'] - df_dur['in_time']

# %%
df_dur
# Out:
#    index                    in_time                  exit_time  \
# 0      1 2022-01-06 19:00:12.899550 2022-01-06 19:00:41.293587
# 1      2 2022-01-06 19:00:14.102361 2022-01-06 19:00:33.787490
# 2      5 2022-01-06 19:00:46.566810 2022-01-06 19:01:13.831532
# 3      6 2022-01-06 19:00:51.758167 2022-01-06 19:01:13.831532
#
#                 start_attend                 end_attend               duration
# 0 2022-01-06 19:00:14.008632 2022-01-06 19:00:34.258307 0 days 00:00:28.394037
# 1 2022-01-06 19:00:17.429740 2022-01-06 19:00:31.031471 0 days 00:00:19.685129
# 2 2022-01-06 19:01:00.662329 2022-01-06 19:01:09.222789 0 days 00:00:27.264722
# 3 2022-01-06 19:00:56.975664 2022-01-06 19:01:16.440286 0 days 00:00:22.073365
